# %% [markdown]
# # Hallucination Detection Data Generation
#
# This notebook runs the automated decompilation metrics pipeline. It integrates similarity analysis (Assembler diff, CFG diff) to enhance the feedback loop for C++ generation.

# %%
# 1. Setup Environment
import os
if not os.path.exists('halluc_detect'):
    # !git clone https://github.com/arnav-chauhan-kgpian/halluc_detect.git
else:
    print("Repository exists.")

# %cd halluc_detect

# %%
# 2. Install Dependencies
# %pip install torch>=2.1 transformers>=4.44 datasets accelerate pandas pyarrow tqdm sentencepiece networkx jsonschema litellm

# %%
# 3. Run the Generation Pipeline
# IMPORTANT: Set --data-path to your Kaggle dataset location
# Example: /kaggle/input/your-dataset/5000_convhash_labels.jsonl
# !python main.py \
    --model Qwen/Qwen3-8B \
    --data-path /kaggle/input/your-dataset-name/5000_convhash_labels.jsonl \
    --max-queries 5000 \
    --output-dir results \
    --dtype bfloat16 \
    --seed 42

# %%
# 4. Zip Results
# !zip -r results_data.zip results/
